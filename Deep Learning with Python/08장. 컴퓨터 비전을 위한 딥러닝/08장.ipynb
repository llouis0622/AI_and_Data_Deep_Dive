# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(inputs)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation='softmax')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        11,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype('float32') / 255
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=5, batch_size=64)
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 14s 14ms/step - accuracy: 0.8824 - loss: 0.3695
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 14s 15ms/step - accuracy: 0.9849 - loss: 0.0476
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 15s 16ms/step - accuracy: 0.9906 - loss: 0.0314
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.9934 - loss: 0.0219
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 16s 17ms/step - accuracy: 0.9951 - loss: 0.0151

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'테스트 정확도 : {test_acc:.3f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9878 - loss: 0.0413
# 테스트 정확도 : 0.991

# %%
inputs = keras.Input(shape=(28, 28, 1))
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(inputs)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(10, activation='softmax')(x)
model_no_max_pool = keras.Model(inputs=inputs, outputs=outputs)

# %%
model_no_max_pool.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 24, 24, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 22, 22, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 61952)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │       619,530 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 712,202 (2.72 MB)
#  Trainable params: 712,202 (2.72 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import os, shutil, pathlib

original_dir = pathlib.Path('../data/dogscats/train')
new_base_dir = pathlib.Path('../data/dogscats/dogscats_small')


def make_subset(subset_name, start_index, end_index):
    for category in ('cat', 'dog'):
        dir = new_base_dir / subset_name / category
        os.makedirs(dir)
        fnames = [f'{category}.{i}.jpg' for i in range(start_index, end_index)]
        for fname in fnames:
            shutil.copyfile(src=original_dir / fname, dst=dir / fname)


make_subset('train', start_index=0, end_index=1000)
make_subset('validation', start_index=1000, end_index=1500)
make_subset('test', start_index=1500, end_index=2500)

# %%
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1. / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 178, 178, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 89, 89, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 87, 87, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 43, 43, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 41, 41, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 20, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 18, 18, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 9, 9, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 7, 7, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │        12,545 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 991,041 (3.78 MB)
#  Trainable params: 991,041 (3.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing import image_dataset_from_directory

train_dataset = image_dataset_from_directory(
    new_base_dir / 'train', image_size=(180, 180), batch_size=32
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / 'validation', image_size=(180, 180), batch_size=32
)
test_dataset = image_dataset_from_directory(
    new_base_dir / 'test', image_size=(180, 180), batch_size=32
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
    print('데이터 배치 크기 : ', data_batch.shape)
    print('레이블 배치 크기 : ', labels_batch.shape)
    break
# Out:
# 데이터 배치 크기 :  (32, 180, 180, 3)
# 레이블 배치 크기 :  (32,)

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='convnet_from_scratch.keras',
        save_best_only=True,
        monitor='val_loss'
    )
]
history = model.fit(train_dataset, epochs=30, validation_data=validation_dataset, callbacks=callbacks)
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 553ms/step - accuracy: 0.4961 - loss: 0.6966 - val_accuracy: 0.5060 - val_loss: 0.6923
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 561ms/step - accuracy: 0.5299 - loss: 0.6999 - val_accuracy: 0.5000 - val_loss: 0.6904
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.5600 - loss: 0.6841 - val_accuracy: 0.6330 - val_loss: 0.6364
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 500ms/step - accuracy: 0.6422 - loss: 0.7247 - val_accuracy: 0.5920 - val_loss: 0.7696
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 501ms/step - accuracy: 0.6342 - loss: 0.6284 - val_accuracy: 0.6480 - val_loss: 0.6254
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 492ms/step - accuracy: 0.7063 - loss: 0.5719 - val_accuracy: 0.6510 - val_loss: 0.6264
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 496ms/step - accuracy: 0.7175 - loss: 0.5649 - val_accuracy: 0.6880 - val_loss: 0.5722
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 493ms/step - accuracy: 0.7410 - loss: 0.5044 - val_accuracy: 0.6750 - val_loss: 0.6020
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 503ms/step - accuracy: 0.7738 - loss: 0.4861 - val_accuracy: 0.6560 - val_loss: 0.6121
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 502ms/step - accuracy: 0.7741 - loss: 0.4770 - val_accuracy: 0.7200 - val_loss: 0.6020
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 517ms/step - accuracy: 0.7936 - loss: 0.4359 - val_accuracy: 0.6580 - val_loss: 0.7313
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 520ms/step - accuracy: 0.8296 - loss: 0.3813 - val_accuracy: 0.7270 - val_loss: 0.5688
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 508ms/step - accuracy: 0.8767 - loss: 0.3064 - val_accuracy: 0.7260 - val_loss: 0.5857
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 513ms/step - accuracy: 0.8811 - loss: 0.2811 - val_accuracy: 0.7340 - val_loss: 0.6640
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 509ms/step - accuracy: 0.9093 - loss: 0.2206 - val_accuracy: 0.6850 - val_loss: 0.8830
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 512ms/step - accuracy: 0.9267 - loss: 0.2035 - val_accuracy: 0.6790 - val_loss: 1.1086
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 580ms/step - accuracy: 0.9380 - loss: 0.1546 - val_accuracy: 0.7000 - val_loss: 1.2021
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 601ms/step - accuracy: 0.9578 - loss: 0.1289 - val_accuracy: 0.7280 - val_loss: 0.9263
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 515ms/step - accuracy: 0.9650 - loss: 0.0945 - val_accuracy: 0.7430 - val_loss: 1.0590
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 515ms/step - accuracy: 0.9758 - loss: 0.0646 - val_accuracy: 0.7050 - val_loss: 1.3133
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 525ms/step - accuracy: 0.9692 - loss: 0.0864 - val_accuracy: 0.7240 - val_loss: 1.4587
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 505ms/step - accuracy: 0.9646 - loss: 0.1013 - val_accuracy: 0.7210 - val_loss: 1.2748
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 483ms/step - accuracy: 0.9873 - loss: 0.0366 - val_accuracy: 0.7400 - val_loss: 1.3539
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 492ms/step - accuracy: 0.9881 - loss: 0.0382 - val_accuracy: 0.7190 - val_loss: 1.8401
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 474ms/step - accuracy: 0.9734 - loss: 0.0702 - val_accuracy: 0.6880 - val_loss: 2.5743
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 471ms/step - accuracy: 0.9615 - loss: 0.1279 - val_accuracy: 0.7320 - val_loss: 1.6270
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 473ms/step - accuracy: 0.9862 - loss: 0.0490 - val_accuracy: 0.7350 - val_loss: 1.7667
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 472ms/step - accuracy: 0.9945 - loss: 0.0169 - val_accuracy: 0.7150 - val_loss: 1.8812
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 471ms/step - accuracy: 0.9859 - loss: 0.0442 - val_accuracy: 0.7290 - val_loss: 1.9664
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 30s 474ms/step - accuracy: 0.9844 - loss: 0.0574 - val_accuracy: 0.7370 - val_loss: 2.0493

# %%
import matplotlib.pyplot as plt

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
test_model = keras.models.load_model('convnet_from_scratch.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f'테스트 정확도 : {test_acc:.3f}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 138ms/step - accuracy: 0.7266 - loss: 0.5950
# 테스트 정확도 : 0.720

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis('off')
# Out:
# 2024-08-16 15:42:12.616384: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1. / 255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation='relu')(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='convnet_from_scratch_with_augmentation.keras',
        save_best_only=True,
        monitor='val_loss'
    )
]
history = model.fit(train_dataset, epochs=100, validation_data=validation_dataset, callbacks=callbacks)
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 556ms/step - accuracy: 0.5249 - loss: 0.7246 - val_accuracy: 0.5000 - val_loss: 0.6916
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 593ms/step - accuracy: 0.5032 - loss: 0.6963 - val_accuracy: 0.5030 - val_loss: 0.6927
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 547ms/step - accuracy: 0.5228 - loss: 0.6963 - val_accuracy: 0.5050 - val_loss: 0.6918
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 528ms/step - accuracy: 0.5276 - loss: 0.6938 - val_accuracy: 0.6180 - val_loss: 0.6701
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 519ms/step - accuracy: 0.5705 - loss: 0.6816 - val_accuracy: 0.6190 - val_loss: 0.6464
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 521ms/step - accuracy: 0.6308 - loss: 0.6511 - val_accuracy: 0.6120 - val_loss: 0.6522
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 528ms/step - accuracy: 0.6180 - loss: 0.6482 - val_accuracy: 0.6140 - val_loss: 0.6514
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.6573 - loss: 0.6316 - val_accuracy: 0.5900 - val_loss: 0.6657
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 523ms/step - accuracy: 0.6373 - loss: 0.6397 - val_accuracy: 0.6210 - val_loss: 0.6484
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 531ms/step - accuracy: 0.6774 - loss: 0.6138 - val_accuracy: 0.6560 - val_loss: 0.6319
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 524ms/step - accuracy: 0.6814 - loss: 0.6050 - val_accuracy: 0.6510 - val_loss: 0.6233
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.6902 - loss: 0.5797 - val_accuracy: 0.6500 - val_loss: 0.6766
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 516ms/step - accuracy: 0.6973 - loss: 0.5734 - val_accuracy: 0.6660 - val_loss: 0.6697
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 530ms/step - accuracy: 0.7020 - loss: 0.5711 - val_accuracy: 0.6340 - val_loss: 0.7945
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 558ms/step - accuracy: 0.7102 - loss: 0.6007 - val_accuracy: 0.7300 - val_loss: 0.5582
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 529ms/step - accuracy: 0.7487 - loss: 0.5196 - val_accuracy: 0.7480 - val_loss: 0.5067
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 531ms/step - accuracy: 0.7384 - loss: 0.5259 - val_accuracy: 0.7720 - val_loss: 0.4978
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 593ms/step - accuracy: 0.7562 - loss: 0.5083 - val_accuracy: 0.7590 - val_loss: 0.4948
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 570ms/step - accuracy: 0.7647 - loss: 0.4798 - val_accuracy: 0.7470 - val_loss: 0.5406
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 544ms/step - accuracy: 0.7863 - loss: 0.4521 - val_accuracy: 0.7440 - val_loss: 0.5344
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 551ms/step - accuracy: 0.7518 - loss: 0.4794 - val_accuracy: 0.7570 - val_loss: 0.5203
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 551ms/step - accuracy: 0.7720 - loss: 0.4762 - val_accuracy: 0.8040 - val_loss: 0.4519
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 525ms/step - accuracy: 0.7847 - loss: 0.4547 - val_accuracy: 0.7770 - val_loss: 0.4660
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 509ms/step - accuracy: 0.7921 - loss: 0.4425 - val_accuracy: 0.7820 - val_loss: 0.4678
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 498ms/step - accuracy: 0.8181 - loss: 0.4212 - val_accuracy: 0.7300 - val_loss: 0.6498
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 497ms/step - accuracy: 0.8027 - loss: 0.4343 - val_accuracy: 0.7570 - val_loss: 0.5255
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 501ms/step - accuracy: 0.8204 - loss: 0.4002 - val_accuracy: 0.7720 - val_loss: 0.4909
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 503ms/step - accuracy: 0.8303 - loss: 0.3946 - val_accuracy: 0.7810 - val_loss: 0.4931
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 506ms/step - accuracy: 0.7925 - loss: 0.4187 - val_accuracy: 0.7640 - val_loss: 0.7315
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 513ms/step - accuracy: 0.8048 - loss: 0.4317 - val_accuracy: 0.7940 - val_loss: 0.5111
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 522ms/step - accuracy: 0.8234 - loss: 0.3969 - val_accuracy: 0.7860 - val_loss: 0.5009
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.8283 - loss: 0.3883 - val_accuracy: 0.7950 - val_loss: 0.4630
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 593ms/step - accuracy: 0.8333 - loss: 0.3649 - val_accuracy: 0.7830 - val_loss: 0.4866
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 627ms/step - accuracy: 0.8303 - loss: 0.3529 - val_accuracy: 0.7740 - val_loss: 0.5149
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 625ms/step - accuracy: 0.8431 - loss: 0.3620 - val_accuracy: 0.8010 - val_loss: 0.4695
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 613ms/step - accuracy: 0.8561 - loss: 0.3434 - val_accuracy: 0.7620 - val_loss: 0.5355
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 614ms/step - accuracy: 0.8361 - loss: 0.3566 - val_accuracy: 0.8040 - val_loss: 0.5109
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 521ms/step - accuracy: 0.8568 - loss: 0.3344 - val_accuracy: 0.7850 - val_loss: 0.5095
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 498ms/step - accuracy: 0.8570 - loss: 0.3181 - val_accuracy: 0.8130 - val_loss: 0.4629
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 561ms/step - accuracy: 0.8648 - loss: 0.3056 - val_accuracy: 0.8230 - val_loss: 0.4429
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 562ms/step - accuracy: 0.8734 - loss: 0.3105 - val_accuracy: 0.8280 - val_loss: 0.4259
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 503ms/step - accuracy: 0.8652 - loss: 0.3085 - val_accuracy: 0.8350 - val_loss: 0.4391
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 494ms/step - accuracy: 0.8827 - loss: 0.2919 - val_accuracy: 0.7950 - val_loss: 0.6131
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 496ms/step - accuracy: 0.8580 - loss: 0.3132 - val_accuracy: 0.8220 - val_loss: 0.4709
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 495ms/step - accuracy: 0.8601 - loss: 0.3124 - val_accuracy: 0.8170 - val_loss: 0.4440
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 494ms/step - accuracy: 0.8856 - loss: 0.2804 - val_accuracy: 0.8140 - val_loss: 0.5325
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 495ms/step - accuracy: 0.8997 - loss: 0.2597 - val_accuracy: 0.7760 - val_loss: 0.7345
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 494ms/step - accuracy: 0.8846 - loss: 0.2782 - val_accuracy: 0.7910 - val_loss: 0.5966
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 495ms/step - accuracy: 0.8913 - loss: 0.2737 - val_accuracy: 0.8260 - val_loss: 0.4872
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 493ms/step - accuracy: 0.8917 - loss: 0.2389 - val_accuracy: 0.7670 - val_loss: 0.6427
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 495ms/step - accuracy: 0.8816 - loss: 0.2730 - val_accuracy: 0.8210 - val_loss: 0.4891
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 495ms/step - accuracy: 0.8947 - loss: 0.2449 - val_accuracy: 0.7850 - val_loss: 0.5882
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 497ms/step - accuracy: 0.9045 - loss: 0.2319 - val_accuracy: 0.8350 - val_loss: 0.5140
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 502ms/step - accuracy: 0.8964 - loss: 0.2507 - val_accuracy: 0.8090 - val_loss: 0.5458
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 31s 498ms/step - accuracy: 0.9053 - loss: 0.2243 - val_accuracy: 0.8340 - val_loss: 0.4924
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 517ms/step - accuracy: 0.8880 - loss: 0.2802 - val_accuracy: 0.8290 - val_loss: 0.4699
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 551ms/step - accuracy: 0.9081 - loss: 0.2452 - val_accuracy: 0.8400 - val_loss: 0.4510
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.9112 - loss: 0.2284 - val_accuracy: 0.7160 - val_loss: 1.0840
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 530ms/step - accuracy: 0.9096 - loss: 0.2530 - val_accuracy: 0.7800 - val_loss: 0.6813
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 608ms/step - accuracy: 0.8951 - loss: 0.2435 - val_accuracy: 0.8220 - val_loss: 0.5029
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 602ms/step - accuracy: 0.9233 - loss: 0.2182 - val_accuracy: 0.8400 - val_loss: 0.4984
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 582ms/step - accuracy: 0.9162 - loss: 0.2220 - val_accuracy: 0.8280 - val_loss: 0.5446
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 36s 570ms/step - accuracy: 0.8958 - loss: 0.2853 - val_accuracy: 0.8330 - val_loss: 0.4974
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 542ms/step - accuracy: 0.9151 - loss: 0.2067 - val_accuracy: 0.7830 - val_loss: 0.6624
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 560ms/step - accuracy: 0.9290 - loss: 0.2018 - val_accuracy: 0.8530 - val_loss: 0.4566
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 562ms/step - accuracy: 0.9180 - loss: 0.2068 - val_accuracy: 0.7980 - val_loss: 0.5639
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 549ms/step - accuracy: 0.9198 - loss: 0.2099 - val_accuracy: 0.8160 - val_loss: 0.5289
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 37s 584ms/step - accuracy: 0.9070 - loss: 0.2356 - val_accuracy: 0.8540 - val_loss: 0.4850
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 622ms/step - accuracy: 0.9356 - loss: 0.1854 - val_accuracy: 0.8480 - val_loss: 0.5254
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 548ms/step - accuracy: 0.9331 - loss: 0.1644 - val_accuracy: 0.8180 - val_loss: 0.6125
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 0.9227 - loss: 0.2202 - val_accuracy: 0.7890 - val_loss: 0.7589
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 38s 598ms/step - accuracy: 0.9189 - loss: 0.2321 - val_accuracy: 0.8480 - val_loss: 0.5290
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 554ms/step - accuracy: 0.9470 - loss: 0.1549 - val_accuracy: 0.8200 - val_loss: 0.6294
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 552ms/step - accuracy: 0.9347 - loss: 0.1668 - val_accuracy: 0.8090 - val_loss: 0.7606
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.9418 - loss: 0.1667 - val_accuracy: 0.8320 - val_loss: 0.5697
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 523ms/step - accuracy: 0.9367 - loss: 0.1765 - val_accuracy: 0.7930 - val_loss: 1.1590
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 535ms/step - accuracy: 0.9347 - loss: 0.1566 - val_accuracy: 0.8330 - val_loss: 0.6720
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.9431 - loss: 0.1642 - val_accuracy: 0.8160 - val_loss: 0.6196
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 0.9312 - loss: 0.1561 - val_accuracy: 0.8450 - val_loss: 0.5282
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 39s 615ms/step - accuracy: 0.9471 - loss: 0.1396 - val_accuracy: 0.8170 - val_loss: 0.5937
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 539ms/step - accuracy: 0.9283 - loss: 0.1872 - val_accuracy: 0.8410 - val_loss: 0.4986
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 517ms/step - accuracy: 0.9480 - loss: 0.1583 - val_accuracy: 0.8200 - val_loss: 0.6444
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 537ms/step - accuracy: 0.9280 - loss: 0.1838 - val_accuracy: 0.8120 - val_loss: 0.6677
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.9342 - loss: 0.1945 - val_accuracy: 0.8440 - val_loss: 0.5189
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 517ms/step - accuracy: 0.9401 - loss: 0.1625 - val_accuracy: 0.8050 - val_loss: 0.6192
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 518ms/step - accuracy: 0.9544 - loss: 0.1330 - val_accuracy: 0.8470 - val_loss: 0.5590
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 530ms/step - accuracy: 0.9517 - loss: 0.1316 - val_accuracy: 0.8340 - val_loss: 0.8073
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.9440 - loss: 0.1708 - val_accuracy: 0.8330 - val_loss: 0.7950
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.9436 - loss: 0.1722 - val_accuracy: 0.8400 - val_loss: 0.5510
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 533ms/step - accuracy: 0.9447 - loss: 0.1574 - val_accuracy: 0.8250 - val_loss: 0.7989
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 538ms/step - accuracy: 0.9544 - loss: 0.1316 - val_accuracy: 0.8330 - val_loss: 0.6426
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 534ms/step - accuracy: 0.9373 - loss: 0.1800 - val_accuracy: 0.8380 - val_loss: 0.6005
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 515ms/step - accuracy: 0.9579 - loss: 0.1099 - val_accuracy: 0.8570 - val_loss: 0.5948
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 526ms/step - accuracy: 0.9570 - loss: 0.1410 - val_accuracy: 0.8330 - val_loss: 0.7118
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 532ms/step - accuracy: 0.9482 - loss: 0.1632 - val_accuracy: 0.8390 - val_loss: 0.6345
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 529ms/step - accuracy: 0.9568 - loss: 0.1262 - val_accuracy: 0.8530 - val_loss: 0.6242
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 527ms/step - accuracy: 0.9459 - loss: 0.1438 - val_accuracy: 0.8520 - val_loss: 0.6591
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 527ms/step - accuracy: 0.9501 - loss: 0.1570 - val_accuracy: 0.8400 - val_loss: 0.5073
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 35s 550ms/step - accuracy: 0.9516 - loss: 0.1449 - val_accuracy: 0.8460 - val_loss: 0.6013
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 34s 541ms/step - accuracy: 0.9405 - loss: 0.1399 - val_accuracy: 0.8430 - val_loss: 0.6811

# %%
test_model = keras.models.load_model('convnet_from_scratch_with_augmentation.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
print('테스트 정확도 : {test_acc:.3f}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 134ms/step - accuracy: 0.8143 - loss: 0.4536
# 테스트 정확도 : {test_acc:.3f}

# %%
conv_base = keras.applications.vgg16.VGG16(weights='imagenet', include_top=False, input_shape=(180, 180, 3))

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 180, 180, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 180, 180, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 180, 180, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 90, 90, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 90, 90, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 90, 90, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 45, 45, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 45, 45, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 45, 45, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 22, 22, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 22, 22, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 22, 22, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 11, 11, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 11, 11, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 5, 5, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
import numpy as np


def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.application.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)


train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 15
#      11         all_labels.append(labels)
#      12     return np.concatenate(all_features), np.concatenate(all_labels)
# ---> 15 train_features, train_labels = get_features_and_labels(train_dataset)
#      16 val_features, val_labels = get_features_and_labels(validation_dataset)
#      17 test_features, test_labels = get_features_and_labels(test_dataset)
#
# Cell In[37], line 8, in get_features_and_labels(dataset)
#       6 all_labels = []
#       7 for images, labels in dataset:
# ----> 8     preprocessed_images = keras.application.vgg16.preprocess_input(images)
#       9     features = conv_base.predict(preprocessed_images)
#      10     all_features.append(features)
#
# AttributeError: module 'keras._tf_keras.keras' has no attribute 'application'

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='feature_extraction.keras', save_best_only=True, monitor='val_loss'
    )
]
history = model.fit(train_features, train_labels, epochs=20,
                    validation_data=(val_features, val_labels), callbacks=callbacks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 13
#       7 model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])
#       8 callbacks = [
#       9     keras.callbacks.ModelCheckpoint(
#      10         filepath='feature_extraction.keras', save_best_only=True, monitor='val_loss'
#      11     )
#      12 ]
# ---> 13 history = model.fit(train_features, train_labels, epochs=20,
#      14                     validation_data=(val_features, val_labels), callbacks=callbacks)
#
# NameError: name 'train_features' is not defined

# %%
import matplotlib.pyplot as plt

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
conv_base = keras.applications.vgg16.VGG16(weights='imagenet', include_top=False)
conv_base.trainable = False

# %%
conv_base.trainable = True
print('합성곱 기반 층을 동결하기 전의 훈련 가능한 가중치 개수 : ', len(conv_base.trainable_weights))
# Out:
# 합성곱 기반 층을 동결하기 전의 훈련 가능한 가중치 개수 :  26

# %%
conv_base.trainable = False
print('합성곱 기반 층을 동결한 후의 훈련 가능한 가중치 개수 : ', len(conv_base.trainable_weights))
# Out:
# 합성곱 기반 층을 동결한 후의 훈련 가능한 가중치 개수 :  0

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
])
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs, outputs)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath='feature_extraction_with_data_augmentation.keras', save_best_only=True, monitor='val_loss'
    )
]
history = model.fit(train_features, train_labels, epochs=50, validation_data=validation_dataset, callbacks=callbacks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 6
#       1 callbacks = [
#       2     keras.callbacks.ModelCheckpoint(
#       3         filepath='feature_extraction_with_data_augmentation.keras', save_best_only=True, monitor='val_loss'
#       4     )
#       5 ]
# ----> 6 history = model.fit(train_features, train_labels, epochs=50, validation_data=validation_dataset, callbacks=callbacks)
#
# NameError: name 'train_features' is not defined

# %%
test_model = keras.models.load_model('feature_extraction_with_data_augmentation.keras')
test_loss, test_acc = test_model.evaluate(test_dataset)
print(f'테스트 정확도 : {test_acc:.3f}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 test_model = keras.models.load_model('feature_extraction_with_data_augmentation.keras')
#       2 test_loss, test_acc = test_model.evaluate(test_dataset)
#       3 print(f'테스트 정확도 : {test_acc:.3f}')
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/saving/saving_api.py:193, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return legacy_h5_format.load_model_from_hdf5(
#     190         filepath, custom_objects=custom_objects, compile=compile
#     191     )
#     192 elif str(filepath).endswith(".keras"):
# --> 193     raise ValueError(
#     194         f"File not found: filepath={filepath}. "
#     195         "Please ensure the file is an accessible `.keras` "
#     196         "zip file."
#     197     )
#     198 else:
#     199     raise ValueError(
#     200         f"File format not supported: filepath={filepath}. "
#     201         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     210         "might have a different name)."
#     211     )
#
# ValueError: File not found: filepath=feature_extraction_with_data_augmentation.keras. Please ensure the file is an accessible `.keras` zip file.

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]:
    layer.trainable = False

# %%
model.compile(loss="binary_crossentropy",
              optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
              metrics=["accuracy"])

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 11
#       1 model.compile(loss="binary_crossentropy",
#       2               optimizer=keras.optimizers.RMSprop(learning_rate=1e-5),
#       3               metrics=["accuracy"])
#       5 callbacks = [
#       6     keras.callbacks.ModelCheckpoint(
#       7         filepath="fine_tuning.keras",
#       8         save_best_only=True,
#       9         monitor="val_loss")
#      10 ]
# ---> 11 history = model.fit(
#      12     train_dataset,
#      13     epochs=30,
#      14     validation_data=validation_dataset,
#      15     callbacks=callbacks)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/input_spec.py:245, in assert_input_compatibility(input_spec, inputs, layer_name)
#     243 if spec_dim is not None and dim is not None:
#     244     if spec_dim != dim:
# --> 245         raise ValueError(
#     246             f'Input {input_index} of layer "{layer_name}" is '
#     247             "incompatible with the layer: "
#     248             f"expected shape={spec.shape}, "
#     249             f"found shape={shape}"
#     250         )
#
# ValueError: Input 0 of layer "functional_8" is incompatible with the layer: expected shape=(None, 5, 5, 512), found shape=(None, 180, 180, 3)

# %%
model = keras.models.load_model("fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset)
print(f"테스트 정확도: {test_acc:.3f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 model = keras.models.load_model("fine_tuning.keras")
#       2 test_loss, test_acc = model.evaluate(test_dataset)
#       3 print(f"테스트 정확도: {test_acc:.3f}")
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/saving/saving_api.py:193, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return legacy_h5_format.load_model_from_hdf5(
#     190         filepath, custom_objects=custom_objects, compile=compile
#     191     )
#     192 elif str(filepath).endswith(".keras"):
# --> 193     raise ValueError(
#     194         f"File not found: filepath={filepath}. "
#     195         "Please ensure the file is an accessible `.keras` "
#     196         "zip file."
#     197     )
#     198 else:
#     199     raise ValueError(
#     200         f"File format not supported: filepath={filepath}. "
#     201         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     210         "might have a different name)."
#     211     )
#
# ValueError: File not found: filepath=fine_tuning.keras. Please ensure the file is an accessible `.keras` zip file.

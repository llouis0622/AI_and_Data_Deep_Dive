# %%
import pylab
import calendar
import numpy as np
import pandas as pd
import seaborn as sn
from scipy import stats
import missingno as msno
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import kendalltau
import warnings
from matplotlib import rc

matplotlib.style.use('ggplot')
pd.options.mode.chained_assignment = None
warnings.filterwarnings("ignore")
# %matplotlib inline
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
train = pd.read_csv('../data/zilow/train_2016_v2.csv', parse_dates=["transactiondate"])
properties = pd.read_csv('../data/zilow/properties_2016.csv')

# %%
print("Shape Of Train: ", train.shape)
print("Shape Of Properties: ", properties.shape)
# Out:
# Shape Of Train:  (90275, 3)
# Shape Of Properties:  (2985217, 58)

# %%
merged = pd.merge(train, properties, on="parcelid", how="left")

# %%
merged.head(3).transpose()
# Out:
#                                                 0                    1  \
# parcelid                                 11016594             14366692
# logerror                                   0.0276              -0.1684
# transactiondate               2016-01-01 00:00:00  2016-01-01 00:00:00
# airconditioningtypeid                         1.0                  NaN
# architecturalstyletypeid                      NaN                  NaN
# basementsqft                                  NaN                  NaN
# bathroomcnt                                   2.0                  3.5
# bedroomcnt                                    3.0                  4.0
# buildingclasstypeid                           NaN                  NaN
# buildingqualitytypeid                         4.0                  NaN
# calculatedbathnbr                             2.0                  3.5
# decktypeid                                    NaN                  NaN
# finishedfloor1squarefeet                      NaN                  NaN
# calculatedfinishedsquarefeet               1684.0               2263.0
# finishedsquarefeet12                       1684.0               2263.0
# finishedsquarefeet13                          NaN                  NaN
# finishedsquarefeet15                          NaN                  NaN
# finishedsquarefeet50                          NaN                  NaN
# finishedsquarefeet6                           NaN                  NaN
# fips                                       6037.0               6059.0
# fireplacecnt                                  NaN                  NaN
# fullbathcnt                                   2.0                  3.0
# garagecarcnt                                  NaN                  2.0
# garagetotalsqft                               NaN                468.0
# hashottuborspa                                NaN                  NaN
# heatingorsystemtypeid                         2.0                  NaN
# latitude                               34280990.0           33668120.0
# longitude                            -118488536.0         -117677556.0
# lotsizesquarefeet                          7528.0               3643.0
# poolcnt                                       NaN                  NaN
# poolsizesum                                   NaN                  NaN
# pooltypeid10                                  NaN                  NaN
# pooltypeid2                                   NaN                  NaN
# pooltypeid7                                   NaN                  NaN
# propertycountylandusecode                    0100                    1
# propertylandusetypeid                       261.0                261.0
# propertyzoningdesc                           LARS                  NaN
# rawcensustractandblock            60371066.461001      60590524.222024
# regionidcity                              12447.0              32380.0
# regionidcounty                             3101.0               1286.0
# regionidneighborhood                      31817.0                  NaN
# regionidzip                               96370.0              96962.0
# roomcnt                                       0.0                  0.0
# storytypeid                                   NaN                  NaN
# threequarterbathnbr                           NaN                  1.0
# typeconstructiontypeid                        NaN                  NaN
# unitcnt                                       1.0                  NaN
# yardbuildingsqft17                            NaN                  NaN
# yardbuildingsqft26                            NaN                  NaN
# yearbuilt                                  1959.0               2014.0
# numberofstories                               NaN                  NaN
# fireplaceflag                                 NaN                  NaN
# structuretaxvaluedollarcnt               122754.0             346458.0
# taxvaluedollarcnt                        360170.0             585529.0
# assessmentyear                             2015.0               2015.0
# landtaxvaluedollarcnt                    237416.0             239071.0
# taxamount                                 6735.88             10153.02
# taxdelinquencyflag                            NaN                  NaN
# taxdelinquencyyear                            NaN                  NaN
# censustractandblock              60371066461001.0                  NaN
#
#                                                 2
# parcelid                                 12098116
# logerror                                   -0.004
# transactiondate               2016-01-01 00:00:00
# airconditioningtypeid                         1.0
# architecturalstyletypeid                      NaN
# basementsqft                                  NaN
# bathroomcnt                                   3.0
# bedroomcnt                                    2.0
# buildingclasstypeid                           NaN
# buildingqualitytypeid                         4.0
# calculatedbathnbr                             3.0
# decktypeid                                    NaN
# finishedfloor1squarefeet                      NaN
# calculatedfinishedsquarefeet               2217.0
# finishedsquarefeet12                       2217.0
# finishedsquarefeet13                          NaN
# finishedsquarefeet15                          NaN
# finishedsquarefeet50                          NaN
# finishedsquarefeet6                           NaN
# fips                                       6037.0
# fireplacecnt                                  NaN
# fullbathcnt                                   3.0
# garagecarcnt                                  NaN
# garagetotalsqft                               NaN
# hashottuborspa                                NaN
# heatingorsystemtypeid                         2.0
# latitude                               34136312.0
# longitude                            -118175032.0
# lotsizesquarefeet                         11423.0
# poolcnt                                       NaN
# poolsizesum                                   NaN
# pooltypeid10                                  NaN
# pooltypeid2                                   NaN
# pooltypeid7                                   NaN
# propertycountylandusecode                    0100
# propertylandusetypeid                       261.0
# propertyzoningdesc                           PSR6
# rawcensustractandblock            60374638.003004
# regionidcity                              47019.0
# regionidcounty                             3101.0
# regionidneighborhood                     275411.0
# regionidzip                               96293.0
# roomcnt                                       0.0
# storytypeid                                   NaN
# threequarterbathnbr                           NaN
# typeconstructiontypeid                        NaN
# unitcnt                                       1.0
# yardbuildingsqft17                            NaN
# yardbuildingsqft26                            NaN
# yearbuilt                                  1940.0
# numberofstories                               NaN
# fireplaceflag                                 NaN
# structuretaxvaluedollarcnt                61994.0
# taxvaluedollarcnt                        119906.0
# assessmentyear                             2015.0
# landtaxvaluedollarcnt                     57912.0
# taxamount                                11484.48
# taxdelinquencyflag                            NaN
# taxdelinquencyyear                            NaN
# censustractandblock              60374638003004.0

# %%
dataTypeDf = pd.DataFrame(merged.dtypes.value_counts()).reset_index().rename(
    columns={"index": "variableType", 0: "count"})
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sn.barplot(data=dataTypeDf, x="variableType", y="count", ax=ax, color="#34495e")
ax.set(xlabel='Variable Type', ylabel='Count', title="Variables Count Across Datatype")
# Out:
# [Text(0.5, 0, 'Variable Type'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Variables Count Across Datatype')]

# %%
missingValueColumns = merged.columns[merged.isnull().any()].tolist()
msno.bar(merged[missingValueColumns], \
         figsize=(20, 8), color="#34495e", fontsize=12, labels=True, )
# Out:
# <Axes: >

# %%
msno.matrix(merged[missingValueColumns], width_ratios=(10, 1), figsize=(20, 8), color=(0, 0, 0), fontsize=12,
            sparkline=True, labels=True)
# Out:
# <Axes: >

# %%
msno.heatmap(merged[missingValueColumns], figsize=(20, 20))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 msno.heatmap(merged[missingValueColumns], figsize=(20, 20))
#
# File /opt/anaconda3/lib/python3.11/site-packages/missingno/missingno.py:398, in heatmap(df, filter, n, p, sort, figsize, fontsize, labels, label_rotation, cmap, vmin, vmax, cbar, ax)
#     395 ax0.patch.set_visible(False)
#     397 for text in ax0.texts:
# --> 398     t = float(text.get_text())
#     399     if 0.95 <= t < 1:
#     400         text.set_text('<1')
#
# ValueError: could not convert string to float: '--'

# %%
from sklearn import model_selection, preprocessing
import xgboost as xgb
import warnings

warnings.filterwarnings("ignore")

mergedFilterd = merged.fillna(-999)
for f in mergedFilterd.columns:
    if mergedFilterd[f].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(mergedFilterd[f].values))
        mergedFilterd[f] = lbl.transform(list(mergedFilterd[f].values))

train_y = mergedFilterd.logerror.values
train_X = mergedFilterd.drop(["parcelid", "transactiondate", "logerror"], axis=1)

xgb_params = {
    'eta': 0.05,
    'max_depth': 8,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'silent': 1
}
dtrain = xgb.DMatrix(train_X, train_y, feature_names=train_X.columns.values)
model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 26
#      15 train_X = mergedFilterd.drop(["parcelid", "transactiondate", "logerror"], axis=1)
#      17 xgb_params = {
#      18     'eta': 0.05,
#      19     'max_depth': 8,
#    (...)
#      24     'silent': 1
#      25 }
# ---> 26 dtrain = xgb.DMatrix(train_X, train_y, feature_names=train_X.columns.values)
#      27 model = xgb.train(dict(xgb_params, silent=0), dtrain, num_boost_round=100)
#
# File /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:730, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     728 for k, arg in zip(sig.parameters, args):
#     729     kwargs[k] = arg
# --> 730 return func(**kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:881, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#     869 self.set_info(
#     870     label=label,
#     871     weight=weight,
#    (...)
#     877     feature_weights=feature_weights,
#     878 )
#     880 if feature_names is not None:
# --> 881     self.feature_names = feature_names
#     882 if feature_types is not None:
#     883     self.feature_types = feature_types
#
# File /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:1302, in DMatrix.feature_names(self, feature_names)
#    1299     return
#    1301 # validate feature name
# -> 1302 feature_names = _validate_feature_info(
#    1303     feature_names, self.num_col(), "feature names"
#    1304 )
#    1305 if len(feature_names) != len(set(feature_names)):
#    1306     values, counts = np.unique(
#    1307         feature_names,
#    1308         return_index=False,
#    1309         return_inverse=False,
#    1310         return_counts=True,
#    1311     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:310, in _validate_feature_info(feature_info, n_features, name)
#     306 def _validate_feature_info(
#     307     feature_info: Sequence[str], n_features: int, name: str
#     308 ) -> List[str]:
#     309     if isinstance(feature_info, str) or not isinstance(feature_info, Sequence):
# --> 310         raise TypeError(
#     311             f"Expecting a sequence of strings for {name}, got: {type(feature_info)}"
#     312         )
#     313     feature_info = list(feature_info)
#     314     if len(feature_info) != n_features and n_features != 0:
#
# TypeError: Expecting a sequence of strings for feature names, got: <class 'numpy.ndarray'>

# %%
featureImportance = model.get_fscore()
features = pd.DataFrame()
features['features'] = featureImportance.keys()
features['importance'] = featureImportance.values()
features.sort_values(by=['importance'], ascending=False, inplace=True)
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
plt.xticks(rotation=90)
sn.barplot(data=features.head(15), x="importance", y="features", ax=ax, orient="h", color="#34495e")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 featureImportance = model.get_fscore()
#       2 features = pd.DataFrame()
#       3 features['features'] = featureImportance.keys()
#
# NameError: name 'model' is not defined

# %%
topFeatures = features["features"].tolist()[:20]
corrMatt = merged[topFeatures].corr()
mask = np.array(corrMatt)
mask[np.tril_indices_from(mask)] = False
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
sn.heatmap(corrMatt, mask=mask, vmax=.8, square=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 topFeatures = features["features"].tolist()[:20]
#       2 corrMatt = merged[topFeatures].corr()
#       3 mask = np.array(corrMatt)
#
# NameError: name 'features' is not defined

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import warnings

warnings.filterwarnings("ignore")


def calculate_vif_(X):
    variables = list(X.columns)
    vif = {variable: variance_inflation_factor(exog=X.values, exog_idx=ix) for ix, variable in
           enumerate(list(X.columns))}
    return vif


numericalCol = []
for f in merged.columns:
    if merged[f].dtype != 'object' and f not in ["parcelid", "transactiondate", "logerror"]:
        numericalCol.append(f)
mergedFilterd = merged[numericalCol].fillna(-999)
vifDict = calculate_vif_(mergedFilterd)

vifDf = pd.DataFrame()
vifDf['variables'] = vifDict.keys()
vifDf['vifScore'] = vifDict.values()
vifDf.sort_values(by=['vifScore'], ascending=False, inplace=True)
validVariables = vifDf[vifDf["vifScore"] <= 5]
variablesWithMC = vifDf[vifDf["vifScore"] > 5]

fig, (ax1, ax2) = plt.subplots(ncols=2)
fig.set_size_inches(20, 8)
sn.barplot(data=validVariables, x="vifScore", y="variables", ax=ax1, orient="h", color="#34495e")
sn.barplot(data=variablesWithMC.head(5), x="vifScore", y="variables", ax=ax2, orient="h", color="#34495e")
ax1.set(xlabel='VIF Scores', ylabel='Features', title="Valid Variables Without Multicollinearity")
ax2.set(xlabel='VIF Scores', ylabel='Features', title="Variables Which Exhibit Multicollinearity")
# Out:
# [Text(0.5, 0, 'VIF Scores'),
#  Text(0, 0.5, 'Features'),
#  Text(0.5, 1.0, 'Variables Which Exhibit Multicollinearity')]

# %%
ulimit = np.percentile(merged.logerror.values, 99)
llimit = np.percentile(merged.logerror.values, 1)
merged.loc[merged['logerror'] > ulimit, 'logerror'] = ulimit
merged.loc[merged['logerror'] < llimit, 'logerror'] = llimit

fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sn.histplot(merged.logerror.values, bins=50, kde=False, color="#34495e", ax=ax)
ax.set(xlabel='logerror', ylabel='Count', title="Distribution Of Dependent Variable")
plt.show()

# %%
train["year"] = train.transactiondate.map(lambda x: str(x).split("-")[0])
train["month"] = train.transactiondate.map(lambda x: str(x).split("-")[1])
train["day"] = train.transactiondate.map(lambda x: str(x).split("-")[2].split()[0])

traingroupedMonth = train.groupby(["month"])["logerror"].mean().to_frame().reset_index()
traingroupedDay = train.groupby(["day"])["logerror"].mean().to_frame().reset_index()
fig, (ax1, ax2) = plt.subplots(nrows=2)
fig.set_size_inches(20, 15)

sn.pointplot(x=traingroupedMonth["month"], y=traingroupedMonth["logerror"], data=traingroupedMonth, join=True, ax=ax1,
             color="#34495e")
ax1.set(xlabel='Month Of The Year', ylabel='Log Error', title="Average Log Error Across Month Of 2016", label='big')

sn.countplot(x=train["month"], data=train, ax=ax2, color="#34495e")
ax2.set(xlabel='Month Of The Year', ylabel='No Of Occurences', title="No Of Occurunces Across Month In 2016",
        label='big')
# Out:
# [Text(0.5, 0, 'Month Of The Year'),
#  Text(0, 0.5, 'No Of Occurences'),
#  Text(0.5, 1.0, 'No Of Occurunces Across Month In 2016'),
#  None]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2)
fig.set_size_inches(20, 15)

sn.pointplot(x=traingroupedDay["day"], y=traingroupedDay["logerror"], data=traingroupedDay, join=True, ax=ax1,
             color="#34495e")
ax1.set(xlabel='Day Of The Month', ylabel='Log Error', title="Average Log Error Across Days Of The Month In 2016",
        label='big')

sn.countplot(x=train["day"], data=train, ax=ax2, color="#34495e")
ax2.set(xlabel='Day Of The Month', ylabel='No Of Occurences', title="No Of Occurences Across Days Of The Month In 2016",
        label='big')
# Out:
# [Text(0.5, 0, 'Day Of The Month'),
#  Text(0, 0.5, 'No Of Occurences'),
#  Text(0.5, 1.0, 'No Of Occurences Across Days Of The Month In 2016'),
#  None]

# %%
fig, ax1 = plt.subplots()
fig.set_size_inches(20, 10)
merged["yearbuilt"] = merged["yearbuilt"].map(lambda x: str(x).split(".")[0])
yearMerged = merged.groupby(['yearbuilt', 'numberofstories'])["parcelid"].count().unstack('numberofstories').fillna(0)
yearMerged.plot(kind='bar', stacked=True, ax=ax1)
# Out:
# <Axes: xlabel='yearbuilt'>

# %%
cols = ["bathroomcnt", "bedroomcnt", "roomcnt", "numberofstories", "logerror", "calculatedfinishedsquarefeet"]
mergedFiltered = merged[cols].dropna()

for col in cols:
    ulimit = np.percentile(mergedFiltered[col].values, 99.5)
    llimit = np.percentile(mergedFiltered[col].values, 0.5)
    mergedFiltered.loc[mergedFiltered[col] > ulimit, col] = ulimit
    mergedFiltered.loc[mergedFiltered[col] < llimit, col] = llimit

# %%
plt.figure(figsize=(8, 8))
sn.jointplot(x=mergedFiltered.calculatedfinishedsquarefeet.values, y=mergedFiltered.logerror.values, size=10,
             kind="hex", color="#34495e")
plt.ylabel('Log Error', fontsize=12)
plt.xlabel('Calculated Finished Square Feet', fontsize=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 plt.figure(figsize=(8, 8))
# ----> 2 sn.jointplot(x=mergedFiltered.calculatedfinishedsquarefeet.values, y=mergedFiltered.logerror.values, size=10,
#       3              kind="hex", color="#34495e")
#       4 plt.ylabel('Log Error', fontsize=12)
#       5 plt.xlabel('Calculated Finished Square Feet', fontsize=12)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:2311, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2309 joint_kws.setdefault("gridsize", gridsize)
#    2310 joint_kws.setdefault("cmap", cmap)
# -> 2311 grid.plot_joint(plt.hexbin, **joint_kws)
#    2313 marginal_kws.setdefault("kde", False)
#    2314 marginal_kws.setdefault("color", color)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:1828, in JointGrid.plot_joint(self, func, **kwargs)
#    1826     func(x=self.x, y=self.y, **kwargs)
#    1827 else:
# -> 1828     func(self.x, self.y, **kwargs)
#    1830 return self
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3172, in hexbin(x, y, C, gridsize, bins, xscale, yscale, extent, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, reduce_C_function, mincnt, marginals, data, **kwargs)
#    3148 @_copy_docstring_and_deprecators(Axes.hexbin)
#    3149 def hexbin(
#    3150     x: ArrayLike,
#    (...)
#    3170     **kwargs,
#    3171 ) -> PolyCollection:
# -> 3172     __ret = gca().hexbin(
#    3173         x,
#    3174         y,
#    3175         C=C,
#    3176         gridsize=gridsize,
#    3177         bins=bins,
#    3178         xscale=xscale,
#    3179         yscale=yscale,
#    3180         extent=extent,
#    3181         cmap=cmap,
#    3182         norm=norm,
#    3183         vmin=vmin,
#    3184         vmax=vmax,
#    3185         alpha=alpha,
#    3186         linewidths=linewidths,
#    3187         edgecolors=edgecolors,
#    3188         reduce_C_function=reduce_C_function,
#    3189         mincnt=mincnt,
#    3190         marginals=marginals,
#    3191         **({"data": data} if data is not None else {}),
#    3192         **kwargs,
#    3193     )
#    3194     sci(__ret)
#    3195     return __ret
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5108, in Axes.hexbin(self, x, y, C, gridsize, bins, xscale, yscale, extent, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, reduce_C_function, mincnt, marginals, **kwargs)
#    5106 collection.set_norm(norm)
#    5107 collection.set_alpha(alpha)
# -> 5108 collection._internal_update(kwargs)
#    5109 collection._scale_norm(norm, vmin, vmax)
#    5111 corners = ((xmin, ymin), (xmax, ymax))
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: PolyCollection.set() got an unexpected keyword argument 'size'

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sn.boxplot(x="bedroomcnt", y="logerror", data=mergedFiltered, ax=ax, color="#34495e")
ax.set(ylabel='Log Error', xlabel="Bedroom Count", title="Bedroom Count Vs Log Error")
# Out:
# [Text(0, 0.5, 'Log Error'),
#  Text(0.5, 0, 'Bedroom Count'),
#  Text(0.5, 1.0, 'Bedroom Count Vs Log Error')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sn.boxplot(x="bathroomcnt", y="logerror", data=mergedFiltered, ax=ax, color="#34495e")
ax.set(ylabel='Log Error', xlabel="Bathroom Count", title="Bathroom Count Vs Log Error")
# Out:
# [Text(0, 0.5, 'Log Error'),
#  Text(0.5, 0, 'Bathroom Count'),
#  Text(0.5, 1.0, 'Bathroom Count Vs Log Error')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sn.boxplot(x="roomcnt", y="logerror", data=mergedFiltered, ax=ax, color="#34495e")
ax.set(ylabel='Log Error', xlabel="Room Count", title="Room Count Vs Log Error")
# Out:
# [Text(0, 0.5, 'Log Error'),
#  Text(0.5, 0, 'Room Count'),
#  Text(0.5, 1.0, 'Room Count Vs Log Error')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 5)
sn.boxplot(x="numberofstories", y="logerror", data=mergedFiltered, ax=ax, color="#34495e")
ax.set(ylabel='Log Error', xlabel="No Of Storeys", title="No Of Storeys Vs Log Error")
# Out:
# [Text(0, 0.5, 'Log Error'),
#  Text(0.5, 0, 'No Of Storeys'),
#  Text(0.5, 1.0, 'No Of Storeys Vs Log Error')]

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot

fig = pylab.figure()
fig.set_size_inches(20, 10)
ax = Axes3D(fig)

ax.scatter(mergedFiltered.bathroomcnt, mergedFiltered.bedroomcnt, mergedFiltered.logerror, color="#34495e")
ax.set_xlabel('Bathroom Count')
ax.set_ylabel('Bedroom Count')
ax.set_zlabel('Log Error')
pyplot.show()

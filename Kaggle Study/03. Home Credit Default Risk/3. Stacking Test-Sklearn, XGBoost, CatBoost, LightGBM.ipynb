# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

NFOLDS = 3
SEED = 0
NROWS = None

data = pd.read_csv('../data/credit/application_train.csv')
test = pd.read_csv('../data/credit/application_test.csv')
prev = pd.read_csv('../data/credit/previous_application.csv')

categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])

gc.enable()

y_train = data['TARGET']
del data['TARGET']

prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])

avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits=NFOLDS, shuffle=True, random_state=SEED)


class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]


class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]


class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))


def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)


et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators': 200,
    'learning_rate': 0.1,
    'num_leaves': 123,
    'colsample_bytree': 0.8,
    'subsample': 0.9,
    'max_depth': 15,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'min_split_gain': 0.01,
    'min_child_weight': 2
}

xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf=CatBoostClassifier, seed=SEED, params=catboost_params)
lg = LightGBMWrapper(clf=LGBMClassifier, seed=SEED, params=lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)

print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))

x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))

logistic_regression = LogisticRegression()
logistic_regression.fit(x_train, y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:, 1]

test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [15:03:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [15:03:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/lib/python3.11/site-packages/xgboost/core.py:160: UserWarning: [15:03:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:742:
# Parameters: { "silent" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# 0:	total: 101ms	remaining: 20.1s
# 1:	total: 126ms	remaining: 12.5s
# 2:	total: 148ms	remaining: 9.75s
# 3:	total: 171ms	remaining: 8.37s
# 4:	total: 194ms	remaining: 7.57s
# 5:	total: 219ms	remaining: 7.09s
# 6:	total: 244ms	remaining: 6.73s
# 7:	total: 271ms	remaining: 6.5s
# 8:	total: 295ms	remaining: 6.27s
# 9:	total: 323ms	remaining: 6.13s
# 10:	total: 351ms	remaining: 6.03s
# 11:	total: 375ms	remaining: 5.87s
# 12:	total: 398ms	remaining: 5.72s
# 13:	total: 422ms	remaining: 5.61s
# 14:	total: 443ms	remaining: 5.47s
# 15:	total: 477ms	remaining: 5.48s
# 16:	total: 514ms	remaining: 5.54s
# 17:	total: 546ms	remaining: 5.52s
# 18:	total: 582ms	remaining: 5.54s
# 19:	total: 606ms	remaining: 5.45s
# 20:	total: 630ms	remaining: 5.37s
# 21:	total: 651ms	remaining: 5.27s
# 22:	total: 674ms	remaining: 5.19s
# 23:	total: 696ms	remaining: 5.1s
# 24:	total: 719ms	remaining: 5.03s
# 25:	total: 741ms	remaining: 4.96s
# 26:	total: 766ms	remaining: 4.91s
# 27:	total: 796ms	remaining: 4.89s
# 28:	total: 825ms	remaining: 4.87s
# 29:	total: 854ms	remaining: 4.84s
# 30:	total: 880ms	remaining: 4.8s
# 31:	total: 904ms	remaining: 4.74s
# 32:	total: 933ms	remaining: 4.72s
# 33:	total: 962ms	remaining: 4.7s
# 34:	total: 989ms	remaining: 4.66s
# 35:	total: 1.02s	remaining: 4.63s
# 36:	total: 1.05s	remaining: 4.64s
# 37:	total: 1.08s	remaining: 4.62s
# 38:	total: 1.12s	remaining: 4.61s
# 39:	total: 1.14s	remaining: 4.55s
# 40:	total: 1.16s	remaining: 4.49s
# 41:	total: 1.18s	remaining: 4.44s
# 42:	total: 1.21s	remaining: 4.41s
# 43:	total: 1.23s	remaining: 4.37s
# 44:	total: 1.26s	remaining: 4.35s
# 45:	total: 1.29s	remaining: 4.32s
# 46:	total: 1.33s	remaining: 4.33s
# 47:	total: 1.36s	remaining: 4.32s
# 48:	total: 1.4s	remaining: 4.3s
# 49:	total: 1.43s	remaining: 4.29s
# 50:	total: 1.47s	remaining: 4.29s
# 51:	total: 1.5s	remaining: 4.28s
# 52:	total: 1.54s	remaining: 4.28s
# 53:	total: 1.58s	remaining: 4.27s
# 54:	total: 1.61s	remaining: 4.25s
# 55:	total: 1.64s	remaining: 4.23s
# 56:	total: 1.68s	remaining: 4.21s
# 57:	total: 1.71s	remaining: 4.18s
# 58:	total: 1.74s	remaining: 4.15s
# 59:	total: 1.76s	remaining: 4.11s
# 60:	total: 1.79s	remaining: 4.08s
# 61:	total: 1.81s	remaining: 4.04s
# 62:	total: 1.84s	remaining: 4.01s
# 63:	total: 1.87s	remaining: 3.98s
# 64:	total: 1.9s	remaining: 3.95s
# 65:	total: 1.94s	remaining: 3.93s
# 66:	total: 1.96s	remaining: 3.9s
# 67:	total: 1.99s	remaining: 3.86s
# 68:	total: 2.01s	remaining: 3.82s
# 69:	total: 2.04s	remaining: 3.78s
# 70:	total: 2.06s	remaining: 3.74s
# 71:	total: 2.08s	remaining: 3.7s
# 72:	total: 2.1s	remaining: 3.66s
# 73:	total: 2.13s	remaining: 3.63s
# 74:	total: 2.16s	remaining: 3.6s
# 75:	total: 2.18s	remaining: 3.56s
# 76:	total: 2.21s	remaining: 3.53s
# 77:	total: 2.23s	remaining: 3.49s
# 78:	total: 2.25s	remaining: 3.45s
# 79:	total: 2.28s	remaining: 3.42s
# 80:	total: 2.3s	remaining: 3.38s
# 81:	total: 2.33s	remaining: 3.35s
# 82:	total: 2.35s	remaining: 3.31s
# 83:	total: 2.38s	remaining: 3.28s
# 84:	total: 2.4s	remaining: 3.25s
# 85:	total: 2.43s	remaining: 3.22s
# 86:	total: 2.45s	remaining: 3.18s
# 87:	total: 2.47s	remaining: 3.14s
# 88:	total: 2.49s	remaining: 3.1s
# 89:	total: 2.51s	remaining: 3.07s
# 90:	total: 2.54s	remaining: 3.04s
# 91:	total: 2.56s	remaining: 3.01s
# 92:	total: 2.59s	remaining: 2.98s
# 93:	total: 2.61s	remaining: 2.95s
# 94:	total: 2.65s	remaining: 2.92s
# 95:	total: 2.67s	remaining: 2.89s
# 96:	total: 2.69s	remaining: 2.86s
# 97:	total: 2.71s	remaining: 2.83s
# 98:	total: 2.74s	remaining: 2.79s
# 99:	total: 2.76s	remaining: 2.76s
# 100:	total: 2.79s	remaining: 2.73s
# 101:	total: 2.81s	remaining: 2.7s
# 102:	total: 2.83s	remaining: 2.67s
# 103:	total: 2.86s	remaining: 2.64s
# 104:	total: 2.89s	remaining: 2.61s
# 105:	total: 2.91s	remaining: 2.58s
# 106:	total: 2.93s	remaining: 2.55s
# 107:	total: 2.96s	remaining: 2.52s
# 108:	total: 2.98s	remaining: 2.49s
# 109:	total: 3.01s	remaining: 2.46s
# 110:	total: 3.03s	remaining: 2.43s
# 111:	total: 3.06s	remaining: 2.4s
# 112:	total: 3.09s	remaining: 2.38s
# 113:	total: 3.11s	remaining: 2.35s
# 114:	total: 3.14s	remaining: 2.32s
# 115:	total: 3.16s	remaining: 2.29s
# 116:	total: 3.19s	remaining: 2.26s
# 117:	total: 3.21s	remaining: 2.23s
# 118:	total: 3.23s	remaining: 2.2s
# 119:	total: 3.26s	remaining: 2.17s
# 120:	total: 3.28s	remaining: 2.14s
# 121:	total: 3.31s	remaining: 2.11s
# 122:	total: 3.33s	remaining: 2.08s
# 123:	total: 3.35s	remaining: 2.06s
# 124:	total: 3.38s	remaining: 2.03s
# 125:	total: 3.4s	remaining: 2s
# 126:	total: 3.43s	remaining: 1.97s
# 127:	total: 3.45s	remaining: 1.94s
# 128:	total: 3.48s	remaining: 1.91s
# 129:	total: 3.51s	remaining: 1.89s
# 130:	total: 3.53s	remaining: 1.86s
# 131:	total: 3.55s	remaining: 1.83s
# 132:	total: 3.57s	remaining: 1.8s
# 133:	total: 3.6s	remaining: 1.77s
# 134:	total: 3.63s	remaining: 1.75s
# 135:	total: 3.65s	remaining: 1.72s
# 136:	total: 3.67s	remaining: 1.69s
# 137:	total: 3.69s	remaining: 1.66s
# 138:	total: 3.72s	remaining: 1.63s
# 139:	total: 3.74s	remaining: 1.6s
# 140:	total: 3.76s	remaining: 1.57s
# 141:	total: 3.78s	remaining: 1.54s
# 142:	total: 3.81s	remaining: 1.52s
# 143:	total: 3.83s	remaining: 1.49s
# 144:	total: 3.86s	remaining: 1.47s
# 145:	total: 3.89s	remaining: 1.44s
# 146:	total: 3.92s	remaining: 1.41s
# 147:	total: 3.96s	remaining: 1.39s
# 148:	total: 3.98s	remaining: 1.36s
# 149:	total: 4.01s	remaining: 1.34s
# 150:	total: 4.03s	remaining: 1.31s
# 151:	total: 4.06s	remaining: 1.28s
# 152:	total: 4.08s	remaining: 1.25s
# 153:	total: 4.11s	remaining: 1.23s
# 154:	total: 4.14s	remaining: 1.2s
# 155:	total: 4.16s	remaining: 1.17s
# 156:	total: 4.19s	remaining: 1.15s
# 157:	total: 4.21s	remaining: 1.12s
# 158:	total: 4.23s	remaining: 1.09s
# 159:	total: 4.26s	remaining: 1.06s
# 160:	total: 4.28s	remaining: 1.04s
# 161:	total: 4.3s	remaining: 1.01s
# 162:	total: 4.33s	remaining: 984ms
# 163:	total: 4.36s	remaining: 958ms
# 164:	total: 4.39s	remaining: 931ms
# 165:	total: 4.41s	remaining: 904ms
# 166:	total: 4.44s	remaining: 877ms
# 167:	total: 4.46s	remaining: 850ms
# 168:	total: 4.49s	remaining: 823ms
# 169:	total: 4.51s	remaining: 796ms
# 170:	total: 4.53s	remaining: 769ms
# 171:	total: 4.56s	remaining: 742ms
# 172:	total: 4.58s	remaining: 715ms
# 173:	total: 4.6s	remaining: 688ms
# 174:	total: 4.63s	remaining: 661ms
# 175:	total: 4.66s	remaining: 635ms
# 176:	total: 4.68s	remaining: 608ms
# 177:	total: 4.7s	remaining: 581ms
# 178:	total: 4.73s	remaining: 555ms
# 179:	total: 4.75s	remaining: 528ms
# 180:	total: 4.78s	remaining: 501ms
# 181:	total: 4.8s	remaining: 475ms
# 182:	total: 4.82s	remaining: 448ms
# 183:	total: 4.85s	remaining: 422ms
# 184:	total: 4.88s	remaining: 396ms
# 185:	total: 4.9s	remaining: 369ms
# 186:	total: 4.94s	remaining: 343ms
# 187:	total: 4.97s	remaining: 317ms
# 188:	total: 4.99s	remaining: 291ms
# 189:	total: 5.01s	remaining: 264ms
# 190:	total: 5.04s	remaining: 237ms
# 191:	total: 5.06s	remaining: 211ms
# 192:	total: 5.08s	remaining: 184ms
# 193:	total: 5.11s	remaining: 158ms
# 194:	total: 5.14s	remaining: 132ms
# 195:	total: 5.16s	remaining: 105ms
# 196:	total: 5.18s	remaining: 79ms
# 197:	total: 5.21s	remaining: 52.7ms
# 198:	total: 5.24s	remaining: 26.3ms
# 199:	total: 5.26s	remaining: 0us
# 0:	total: 34.6ms	remaining: 6.89s
# 1:	total: 62.3ms	remaining: 6.17s
# 2:	total: 90.4ms	remaining: 5.94s
# 3:	total: 113ms	remaining: 5.55s
# 4:	total: 137ms	remaining: 5.34s
# 5:	total: 159ms	remaining: 5.14s
# 6:	total: 183ms	remaining: 5.06s
# 7:	total: 206ms	remaining: 4.94s
# 8:	total: 224ms	remaining: 4.75s
# 9:	total: 245ms	remaining: 4.65s
# 10:	total: 268ms	remaining: 4.6s
# 11:	total: 292ms	remaining: 4.57s
# 12:	total: 313ms	remaining: 4.5s
# 13:	total: 336ms	remaining: 4.46s
# 14:	total: 357ms	remaining: 4.41s
# 15:	total: 380ms	remaining: 4.37s
# 16:	total: 403ms	remaining: 4.34s
# 17:	total: 424ms	remaining: 4.29s
# 18:	total: 442ms	remaining: 4.21s
# 19:	total: 468ms	remaining: 4.21s
# 20:	total: 488ms	remaining: 4.16s
# 21:	total: 510ms	remaining: 4.13s
# 22:	total: 533ms	remaining: 4.1s
# 23:	total: 554ms	remaining: 4.06s
# 24:	total: 574ms	remaining: 4.02s
# 25:	total: 594ms	remaining: 3.97s
# 26:	total: 611ms	remaining: 3.92s
# 27:	total: 631ms	remaining: 3.88s
# 28:	total: 655ms	remaining: 3.86s
# 29:	total: 677ms	remaining: 3.83s
# 30:	total: 699ms	remaining: 3.81s
# 31:	total: 723ms	remaining: 3.8s
# 32:	total: 744ms	remaining: 3.77s
# 33:	total: 765ms	remaining: 3.74s
# 34:	total: 787ms	remaining: 3.71s
# 35:	total: 805ms	remaining: 3.67s
# 36:	total: 826ms	remaining: 3.64s
# 37:	total: 846ms	remaining: 3.61s
# 38:	total: 864ms	remaining: 3.57s
# 39:	total: 886ms	remaining: 3.54s
# 40:	total: 908ms	remaining: 3.52s
# 41:	total: 932ms	remaining: 3.51s
# 42:	total: 953ms	remaining: 3.48s
# 43:	total: 973ms	remaining: 3.45s
# 44:	total: 999ms	remaining: 3.44s
# 45:	total: 1.02s	remaining: 3.41s
# 46:	total: 1.04s	remaining: 3.39s
# 47:	total: 1.06s	remaining: 3.37s
# 48:	total: 1.08s	remaining: 3.34s
# 49:	total: 1.1s	remaining: 3.31s
# 50:	total: 1.13s	remaining: 3.29s
# 51:	total: 1.15s	remaining: 3.26s
# 52:	total: 1.17s	remaining: 3.23s
# 53:	total: 1.19s	remaining: 3.21s
# 54:	total: 1.21s	remaining: 3.19s
# 55:	total: 1.23s	remaining: 3.17s
# 56:	total: 1.25s	remaining: 3.14s
# 57:	total: 1.27s	remaining: 3.11s
# 58:	total: 1.29s	remaining: 3.08s
# 59:	total: 1.31s	remaining: 3.06s
# 60:	total: 1.33s	remaining: 3.04s
# 61:	total: 1.36s	remaining: 3.02s
# 62:	total: 1.38s	remaining: 3s
# 63:	total: 1.4s	remaining: 2.98s
# 64:	total: 1.43s	remaining: 2.96s
# 65:	total: 1.45s	remaining: 2.95s
# 66:	total: 1.47s	remaining: 2.92s
# 67:	total: 1.49s	remaining: 2.9s
# 68:	total: 1.51s	remaining: 2.87s
# 69:	total: 1.53s	remaining: 2.85s
# 70:	total: 1.55s	remaining: 2.82s
# 71:	total: 1.57s	remaining: 2.79s
# 72:	total: 1.59s	remaining: 2.77s
# 73:	total: 1.61s	remaining: 2.75s
# 74:	total: 1.64s	remaining: 2.73s
# 75:	total: 1.66s	remaining: 2.71s
# 76:	total: 1.68s	remaining: 2.68s
# 77:	total: 1.7s	remaining: 2.66s
# 78:	total: 1.72s	remaining: 2.63s
# 79:	total: 1.74s	remaining: 2.61s
# 80:	total: 1.76s	remaining: 2.58s
# 81:	total: 1.78s	remaining: 2.56s
# 82:	total: 1.8s	remaining: 2.54s
# 83:	total: 1.83s	remaining: 2.52s
# 84:	total: 1.85s	remaining: 2.51s
# 85:	total: 1.87s	remaining: 2.48s
# 86:	total: 1.89s	remaining: 2.46s
# 87:	total: 1.92s	remaining: 2.44s
# 88:	total: 1.93s	remaining: 2.41s
# 89:	total: 1.96s	remaining: 2.39s
# 90:	total: 1.98s	remaining: 2.37s
# 91:	total: 2s	remaining: 2.35s
# 92:	total: 2.02s	remaining: 2.32s
# 93:	total: 2.04s	remaining: 2.31s
# 94:	total: 2.07s	remaining: 2.28s
# 95:	total: 2.09s	remaining: 2.26s
# 96:	total: 2.1s	remaining: 2.23s
# 97:	total: 2.12s	remaining: 2.21s
# 98:	total: 2.14s	remaining: 2.18s
# 99:	total: 2.16s	remaining: 2.16s
# 100:	total: 2.18s	remaining: 2.14s
# 101:	total: 2.2s	remaining: 2.12s
# 102:	total: 2.23s	remaining: 2.1s
# 103:	total: 2.25s	remaining: 2.08s
# 104:	total: 2.27s	remaining: 2.05s
# 105:	total: 2.29s	remaining: 2.03s
# 106:	total: 2.31s	remaining: 2.01s
# 107:	total: 2.33s	remaining: 1.98s
# 108:	total: 2.35s	remaining: 1.96s
# 109:	total: 2.37s	remaining: 1.94s
# 110:	total: 2.39s	remaining: 1.92s
# 111:	total: 2.41s	remaining: 1.9s
# 112:	total: 2.43s	remaining: 1.87s
# 113:	total: 2.46s	remaining: 1.85s
# 114:	total: 2.47s	remaining: 1.83s
# 115:	total: 2.5s	remaining: 1.81s
# 116:	total: 2.52s	remaining: 1.79s
# 117:	total: 2.54s	remaining: 1.76s
# 118:	total: 2.56s	remaining: 1.74s
# 119:	total: 2.58s	remaining: 1.72s
# 120:	total: 2.6s	remaining: 1.7s
# 121:	total: 2.62s	remaining: 1.68s
# 122:	total: 2.65s	remaining: 1.66s
# 123:	total: 2.67s	remaining: 1.64s
# 124:	total: 2.69s	remaining: 1.61s
# 125:	total: 2.71s	remaining: 1.59s
# 126:	total: 2.73s	remaining: 1.57s
# 127:	total: 2.75s	remaining: 1.55s
# 128:	total: 2.77s	remaining: 1.52s
# 129:	total: 2.79s	remaining: 1.5s
# 130:	total: 2.81s	remaining: 1.48s
# 131:	total: 2.83s	remaining: 1.46s
# 132:	total: 2.86s	remaining: 1.44s
# 133:	total: 2.88s	remaining: 1.42s
# 134:	total: 2.9s	remaining: 1.4s
# 135:	total: 2.92s	remaining: 1.38s
# 136:	total: 2.94s	remaining: 1.35s
# 137:	total: 2.96s	remaining: 1.33s
# 138:	total: 2.98s	remaining: 1.31s
# 139:	total: 3s	remaining: 1.29s
# 140:	total: 3.03s	remaining: 1.27s
# 141:	total: 3.05s	remaining: 1.25s
# 142:	total: 3.08s	remaining: 1.23s
# 143:	total: 3.1s	remaining: 1.21s
# 144:	total: 3.13s	remaining: 1.19s
# 145:	total: 3.17s	remaining: 1.17s
# 146:	total: 3.19s	remaining: 1.15s
# 147:	total: 3.21s	remaining: 1.13s
# 148:	total: 3.23s	remaining: 1.1s
# 149:	total: 3.25s	remaining: 1.08s
# 150:	total: 3.27s	remaining: 1.06s
# 151:	total: 3.29s	remaining: 1.04s
# 152:	total: 3.32s	remaining: 1.02s
# 153:	total: 3.34s	remaining: 997ms
# 154:	total: 3.36s	remaining: 976ms
# 155:	total: 3.38s	remaining: 954ms
# 156:	total: 3.4s	remaining: 932ms
# 157:	total: 3.42s	remaining: 910ms
# 158:	total: 3.44s	remaining: 888ms
# 159:	total: 3.46s	remaining: 866ms
# 160:	total: 3.49s	remaining: 846ms
# 161:	total: 3.51s	remaining: 824ms
# 162:	total: 3.54s	remaining: 803ms
# 163:	total: 3.56s	remaining: 781ms
# 164:	total: 3.58s	remaining: 759ms
# 165:	total: 3.6s	remaining: 737ms
# 166:	total: 3.62s	remaining: 715ms
# 167:	total: 3.64s	remaining: 693ms
# 168:	total: 3.66s	remaining: 671ms
# 169:	total: 3.68s	remaining: 650ms
# 170:	total: 3.71s	remaining: 628ms
# 171:	total: 3.73s	remaining: 607ms
# 172:	total: 3.75s	remaining: 585ms
# 173:	total: 3.77s	remaining: 564ms
# 174:	total: 3.79s	remaining: 542ms
# 175:	total: 3.81s	remaining: 520ms
# 176:	total: 3.83s	remaining: 498ms
# 177:	total: 3.85s	remaining: 476ms
# 178:	total: 3.87s	remaining: 454ms
# 179:	total: 3.89s	remaining: 433ms
# 180:	total: 3.92s	remaining: 412ms
# 181:	total: 3.94s	remaining: 390ms
# 182:	total: 3.96s	remaining: 368ms
# 183:	total: 3.98s	remaining: 346ms
# 184:	total: 4s	remaining: 325ms
# 185:	total: 4.02s	remaining: 303ms
# 186:	total: 4.04s	remaining: 281ms
# 187:	total: 4.06s	remaining: 259ms
# 188:	total: 4.08s	remaining: 238ms
# 189:	total: 4.11s	remaining: 216ms
# 190:	total: 4.13s	remaining: 194ms
# 191:	total: 4.15s	remaining: 173ms
# 192:	total: 4.17s	remaining: 151ms
# 193:	total: 4.19s	remaining: 130ms
# 194:	total: 4.21s	remaining: 108ms
# 195:	total: 4.23s	remaining: 86.3ms
# 196:	total: 4.25s	remaining: 64.7ms
# 197:	total: 4.27s	remaining: 43.2ms
# 198:	total: 4.29s	remaining: 21.6ms
# 199:	total: 4.31s	remaining: 0us
# 0:	total: 23.7ms	remaining: 4.72s
# 1:	total: 45.1ms	remaining: 4.47s
# 2:	total: 65.8ms	remaining: 4.32s
# 3:	total: 86.2ms	remaining: 4.22s
# 4:	total: 103ms	remaining: 4.03s
# 5:	total: 123ms	remaining: 3.98s
# 6:	total: 144ms	remaining: 3.96s
# 7:	total: 165ms	remaining: 3.95s
# 8:	total: 184ms	remaining: 3.9s
# 9:	total: 214ms	remaining: 4.07s
# 10:	total: 247ms	remaining: 4.25s
# 11:	total: 297ms	remaining: 4.65s
# 12:	total: 341ms	remaining: 4.9s
# 13:	total: 376ms	remaining: 4.99s
# 14:	total: 422ms	remaining: 5.2s
# 15:	total: 450ms	remaining: 5.18s
# 16:	total: 477ms	remaining: 5.13s
# 17:	total: 506ms	remaining: 5.12s
# 18:	total: 568ms	remaining: 5.42s
# 19:	total: 603ms	remaining: 5.43s
# 20:	total: 627ms	remaining: 5.34s
# 21:	total: 652ms	remaining: 5.28s
# 22:	total: 679ms	remaining: 5.22s
# 23:	total: 705ms	remaining: 5.17s
# 24:	total: 726ms	remaining: 5.08s
# 25:	total: 745ms	remaining: 4.99s
# 26:	total: 768ms	remaining: 4.92s
# 27:	total: 786ms	remaining: 4.83s
# 28:	total: 805ms	remaining: 4.75s
# 29:	total: 824ms	remaining: 4.67s
# 30:	total: 846ms	remaining: 4.61s
# 31:	total: 864ms	remaining: 4.54s
# 32:	total: 885ms	remaining: 4.48s
# 33:	total: 907ms	remaining: 4.42s
# 34:	total: 930ms	remaining: 4.38s
# 35:	total: 954ms	remaining: 4.34s
# 36:	total: 976ms	remaining: 4.3s
# 37:	total: 996ms	remaining: 4.25s
# 38:	total: 1.02s	remaining: 4.2s
# 39:	total: 1.04s	remaining: 4.15s
# 40:	total: 1.06s	remaining: 4.11s
# 41:	total: 1.08s	remaining: 4.06s
# 42:	total: 1.1s	remaining: 4.04s
# 43:	total: 1.13s	remaining: 3.99s
# 44:	total: 1.15s	remaining: 3.96s
# 45:	total: 1.17s	remaining: 3.93s
# 46:	total: 1.23s	remaining: 4s
# 47:	total: 1.27s	remaining: 4.01s
# 48:	total: 1.3s	remaining: 4s
# 49:	total: 1.33s	remaining: 4s
# 50:	total: 1.36s	remaining: 3.97s
# 51:	total: 1.38s	remaining: 3.92s
# 52:	total: 1.41s	remaining: 3.92s
# 53:	total: 1.44s	remaining: 3.88s
# 54:	total: 1.46s	remaining: 3.85s
# 55:	total: 1.48s	remaining: 3.81s
# 56:	total: 1.5s	remaining: 3.77s
# 57:	total: 1.52s	remaining: 3.72s
# 58:	total: 1.54s	remaining: 3.68s
# 59:	total: 1.56s	remaining: 3.65s
# 60:	total: 1.58s	remaining: 3.61s
# 61:	total: 1.61s	remaining: 3.58s
# 62:	total: 1.63s	remaining: 3.55s
# 63:	total: 1.65s	remaining: 3.51s
# 64:	total: 1.67s	remaining: 3.47s
# 65:	total: 1.69s	remaining: 3.43s
# 66:	total: 1.71s	remaining: 3.39s
# 67:	total: 1.73s	remaining: 3.35s
# 68:	total: 1.75s	remaining: 3.31s
# 69:	total: 1.77s	remaining: 3.29s
# 70:	total: 1.79s	remaining: 3.26s
# 71:	total: 1.82s	remaining: 3.23s
# 72:	total: 1.84s	remaining: 3.19s
# 73:	total: 1.86s	remaining: 3.17s
# 74:	total: 1.88s	remaining: 3.14s
# 75:	total: 1.9s	remaining: 3.11s
# 76:	total: 1.92s	remaining: 3.07s
# 77:	total: 1.94s	remaining: 3.04s
# 78:	total: 1.97s	remaining: 3.01s
# 79:	total: 1.99s	remaining: 2.98s
# 80:	total: 2.01s	remaining: 2.96s
# 81:	total: 2.03s	remaining: 2.92s
# 82:	total: 2.05s	remaining: 2.89s
# 83:	total: 2.07s	remaining: 2.86s
# 84:	total: 2.09s	remaining: 2.83s
# 85:	total: 2.12s	remaining: 2.8s
# 86:	total: 2.13s	remaining: 2.77s
# 87:	total: 2.16s	remaining: 2.74s
# 88:	total: 2.18s	remaining: 2.72s
# 89:	total: 2.2s	remaining: 2.69s
# 90:	total: 2.22s	remaining: 2.66s
# 91:	total: 2.24s	remaining: 2.63s
# 92:	total: 2.26s	remaining: 2.6s
# 93:	total: 2.28s	remaining: 2.57s
# 94:	total: 2.3s	remaining: 2.54s
# 95:	total: 2.32s	remaining: 2.52s
# 96:	total: 2.34s	remaining: 2.49s
# 97:	total: 2.36s	remaining: 2.46s
# 98:	total: 2.38s	remaining: 2.43s
# 99:	total: 2.41s	remaining: 2.41s
# 100:	total: 2.43s	remaining: 2.38s
# 101:	total: 2.45s	remaining: 2.35s
# 102:	total: 2.47s	remaining: 2.33s
# 103:	total: 2.49s	remaining: 2.3s
# 104:	total: 2.51s	remaining: 2.27s
# 105:	total: 2.53s	remaining: 2.25s
# 106:	total: 2.55s	remaining: 2.22s
# 107:	total: 2.58s	remaining: 2.19s
# 108:	total: 2.6s	remaining: 2.17s
# 109:	total: 2.62s	remaining: 2.14s
# 110:	total: 2.64s	remaining: 2.12s
# 111:	total: 2.66s	remaining: 2.09s
# 112:	total: 2.68s	remaining: 2.06s
# 113:	total: 2.7s	remaining: 2.04s
# 114:	total: 2.72s	remaining: 2.01s
# 115:	total: 2.74s	remaining: 1.99s
# 116:	total: 2.77s	remaining: 1.96s
# 117:	total: 2.79s	remaining: 1.94s
# 118:	total: 2.81s	remaining: 1.91s
# 119:	total: 2.83s	remaining: 1.89s
# 120:	total: 2.85s	remaining: 1.86s
# 121:	total: 2.87s	remaining: 1.83s
# 122:	total: 2.89s	remaining: 1.81s
# 123:	total: 2.91s	remaining: 1.78s
# 124:	total: 2.93s	remaining: 1.76s
# 125:	total: 2.95s	remaining: 1.73s
# 126:	total: 2.98s	remaining: 1.71s
# 127:	total: 3s	remaining: 1.69s
# 128:	total: 3.02s	remaining: 1.66s
# 129:	total: 3.05s	remaining: 1.64s
# 130:	total: 3.07s	remaining: 1.62s
# 131:	total: 3.09s	remaining: 1.59s
# 132:	total: 3.12s	remaining: 1.57s
# 133:	total: 3.14s	remaining: 1.54s
# 134:	total: 3.16s	remaining: 1.52s
# 135:	total: 3.18s	remaining: 1.5s
# 136:	total: 3.2s	remaining: 1.47s
# 137:	total: 3.22s	remaining: 1.45s
# 138:	total: 3.24s	remaining: 1.42s
# 139:	total: 3.26s	remaining: 1.4s
# 140:	total: 3.29s	remaining: 1.37s
# 141:	total: 3.31s	remaining: 1.35s
# 142:	total: 3.33s	remaining: 1.33s
# 143:	total: 3.35s	remaining: 1.3s
# 144:	total: 3.37s	remaining: 1.28s
# 145:	total: 3.39s	remaining: 1.25s
# 146:	total: 3.41s	remaining: 1.23s
# 147:	total: 3.43s	remaining: 1.21s
# 148:	total: 3.45s	remaining: 1.18s
# 149:	total: 3.48s	remaining: 1.16s
# 150:	total: 3.5s	remaining: 1.14s
# 151:	total: 3.53s	remaining: 1.11s
# 152:	total: 3.55s	remaining: 1.09s
# 153:	total: 3.57s	remaining: 1.07s
# 154:	total: 3.59s	remaining: 1.04s
# 155:	total: 3.61s	remaining: 1.02s
# 156:	total: 3.63s	remaining: 994ms
# 157:	total: 3.65s	remaining: 969ms
# 158:	total: 3.67s	remaining: 946ms
# 159:	total: 3.69s	remaining: 923ms
# 160:	total: 3.71s	remaining: 900ms
# 161:	total: 3.74s	remaining: 876ms
# 162:	total: 3.76s	remaining: 853ms
# 163:	total: 3.78s	remaining: 829ms
# 164:	total: 3.8s	remaining: 806ms
# 165:	total: 3.82s	remaining: 782ms
# 166:	total: 3.84s	remaining: 759ms
# 167:	total: 3.86s	remaining: 735ms
# 168:	total: 3.88s	remaining: 713ms
# 169:	total: 3.91s	remaining: 690ms
# 170:	total: 3.93s	remaining: 666ms
# 171:	total: 3.95s	remaining: 643ms
# 172:	total: 3.97s	remaining: 619ms
# 173:	total: 3.99s	remaining: 596ms
# 174:	total: 4.01s	remaining: 572ms
# 175:	total: 4.02s	remaining: 549ms
# 176:	total: 4.04s	remaining: 525ms
# 177:	total: 4.07s	remaining: 502ms
# 178:	total: 4.09s	remaining: 479ms
# 179:	total: 4.11s	remaining: 456ms
# 180:	total: 4.13s	remaining: 434ms
# 181:	total: 4.15s	remaining: 411ms
# 182:	total: 4.17s	remaining: 388ms
# 183:	total: 4.19s	remaining: 365ms
# 184:	total: 4.21s	remaining: 342ms
# 185:	total: 4.23s	remaining: 319ms
# 186:	total: 4.25s	remaining: 296ms
# 187:	total: 4.27s	remaining: 273ms
# 188:	total: 4.29s	remaining: 250ms
# 189:	total: 4.31s	remaining: 227ms
# 190:	total: 4.33s	remaining: 204ms
# 191:	total: 4.35s	remaining: 181ms
# 192:	total: 4.37s	remaining: 159ms
# 193:	total: 4.39s	remaining: 136ms
# 194:	total: 4.42s	remaining: 113ms
# 195:	total: 4.44s	remaining: 90.6ms
# 196:	total: 4.46s	remaining: 67.9ms
# 197:	total: 4.48s	remaining: 45.2ms
# 198:	total: 4.5s	remaining: 22.6ms
# 199:	total: 4.52s	remaining: 0us
# XG-CV: 0.2597969273328384
# ET-CV: 0.2629551646344453
# RF-CV: 0.26297423474949516
# RF-CV: 0.3306000196333401
# (307511, 4),(48744, 4)
